# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_2022 = pd.read_csv(r"C:\Users\91891\Downloads\World_Hapinees_Report\2022.csv")

# %%
df_2022.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# ...

# %%
df_2022.shape
# Out:
# (147, 12)

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        147 non-null    int64
#  1   Country                                     147 non-null    object
#  2   Happiness score                             146 non-null    object
#  3   Whisker-high                                146 non-null    object
#  4   Whisker-low                                 146 non-null    object
#  5   Dystopia (1.83) + residual                  146 non-null    object
#  6   Explained by: GDP per capita                146 non-null    object
#  7   Explained by: Social support                146 non-null    object
#  8   Explained by: Healthy life expectancy       146 non-null    object
#  9   Explained by: Freedom to make life choices  146 non-null    object
# ...

# %%
df_2022.dtypes
# Out:
# RANK                                           int64
# Country                                       object
# Happiness score                               object
# Whisker-high                                  object
# Whisker-low                                   object
# Dystopia (1.83) + residual                    object
# Explained by: GDP per capita                  object
# Explained by: Social support                  object
# Explained by: Healthy life expectancy         object
# Explained by: Freedom to make life choices    object
# Explained by: Generosity                      object
# Explained by: Perceptions of corruption       object
# dtype: object

# %% [markdown]
# **The datatype of most of the variables are incorrect. So we need to change the datatypes of these columns.**

# %%
df_2022.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
for i in ['Happiness score', 'Whisker-high', 'Whisker-low',
       'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
       'Explained by: Social support', 'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption']:
    df_2022[i]=df_2022[i].apply(lambda x: str(x).replace(',','.'))

# %%
df_2022.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7.821        7.886       7.756
# 1     2      Denmark           7.636        7.710       7.563
# 2     3      Iceland           7.557        7.651       7.464
# 3     4  Switzerland           7.512        7.586       7.437
# 4     5  Netherlands           7.415        7.471       7.359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2.518                        1.892
# 1                      2.226                        1.953
# 2                      2.320                        1.936
# 3                      2.153                        2.026
# 4                      2.137                        1.945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1.258                                 0.775
# 1                        1.243                                 0.777
# ...

# %%
for i in ['Happiness score', 'Whisker-high', 'Whisker-low',
       'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
       'Explained by: Social support', 'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption']:
    df_2022[i] = df_2022[i].astype(float)

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        147 non-null    int64
#  1   Country                                     147 non-null    object
#  2   Happiness score                             146 non-null    float64
#  3   Whisker-high                                146 non-null    float64
#  4   Whisker-low                                 146 non-null    float64
#  5   Dystopia (1.83) + residual                  146 non-null    float64
#  6   Explained by: GDP per capita                146 non-null    float64
#  7   Explained by: Social support                146 non-null    float64
#  8   Explained by: Healthy life expectancy       146 non-null    float64
# ...

# %%
df_2022.hist(figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'RANK'}>,
#         <AxesSubplot:title={'center':'Happiness score'}>,
#         <AxesSubplot:title={'center':'Whisker-high'}>],
#        [<AxesSubplot:title={'center':'Whisker-low'}>,
#         <AxesSubplot:title={'center':'Dystopia (1.83) + residual'}>,
#         <AxesSubplot:title={'center':'Explained by: GDP per capita'}>],
#        [<AxesSubplot:title={'center':'Explained by: Social support'}>,
#         <AxesSubplot:title={'center':'Explained by: Healthy life expectancy'}>,
#         <AxesSubplot:title={'center':'Explained by: Freedom to make life choices'}>],
#        [<AxesSubplot:title={'center':'Explained by: Generosity'}>,
#         <AxesSubplot:title={'center':'Explained by: Perceptions of corruption'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(10,60))
plt.subplot(2,1,1)
plt.xticks(rotation = 90)
sns.barplot(df_2022['Explained by: Perceptions of corruption'], df_2022['Country'], palette='bright').set_title('Countries and their Perceptions of corruption scores', fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Countries and their Perceptions of corruption scores')

# %%
plt.figure(figsize=(10,60))
plt.subplot(2,1,1)
plt.xticks(rotation = 90)
sns.barplot(df_2022['Explained by: Generosity'], df_2022['Country'], palette='bright').set_title('Countries and their Generosity scores', fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Countries and their Generosity scores')

# %%
plt.figure(figsize=(10,60))

plt.subplot(2,1,1)
plt.xticks(rotation = 90)
sns.barplot(df_2022['Explained by: Freedom to make life choices'], df_2022['Country'], palette='bright').set_title('Countries and their Freedom to make life choices scores', fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Countries and their Freedom to make life choices scores')

# %%
plt.figure(figsize=(10,60))
plt.subplot(2,1,1)
plt.xticks(rotation = 90)
sns.barplot(df_2022['Explained by: Healthy life expectancy'], df_2022['Country'], palette='bright').set_title('Countries and their Healthy life expectancy scores', fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Countries and their Healthy life expectancy scores')

# %%
plt.figure(figsize=(10,60))
plt.subplot(2,1,1)
plt.xticks(rotation = 90)
sns.barplot(df_2022['Explained by: Social support'], df_2022['Country'], palette='bright').set_title('Countries and their Social support scores', fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Countries and their Social support scores')

# %%
plt.figure(figsize=(10,60))
plt.subplot(2,1,1)
plt.xticks(rotation = 90)
sns.barplot(df_2022['Explained by: GDP per capita'], df_2022['Country'], palette='bright').set_title('Countries and their GDP per capita scores', fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Countries and their GDP per capita scores')

# %%
plt.figure(figsize=(10,60))
plt.subplot(2,1,1)
plt.xticks(rotation = 90)
sns.barplot(df_2022['Dystopia (1.83) + residual'], df_2022['Country'], palette='bright').set_title("Countries and their 'Dystopia (1.83) + residual' scores", fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, "Countries and their 'Dystopia (1.83) + residual' scores")

# %%
df_2022.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: Perceptions of corruption'], df_2022['Happiness score']).set_title("Happiness score vs Perceptions of corruption",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Perceptions of corruption')

# %% [markdown]
# **The above plot shows that Happiness score increase with the increase in Perception of corruption score. There is only one exception which is the country of Rwanda**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Dystopia (1.83) + residual'], df_2022['Happiness score']).set_title("Happiness score vs Dystopia (1.83) + residual", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Dystopia (1.83) + residual')

# %% [markdown]
# **The above plot shows that Happiness score increase with the increase in the 'Dystopia (1.83) + residual' score.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: GDP per capita'], df_2022['Happiness score']).set_title("Happiness score vs GDP per capita", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Happiness score vs GDP per capita')

# %% [markdown]
# **The above plot shows that Happiness score increase with the increase in the GDP per capita.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: Social support'], df_2022['Happiness score']).set_title("Happiness score vs Social support", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Social support')

# %% [markdown]
# **The above plot shows that Happiness score increase with the increase in the Social support score.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: Healthy life expectancy'], df_2022['Happiness score']).set_title("Happiness score vs Healthy life expectancy",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Healthy life expectancy')

# %% [markdown]
# **The above plot shows that Happiness score increase with the increase in the 'Healthy life expectancy' score.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: Freedom to make life choices'], df_2022['Happiness score']).set_title("Happiness score vs Freedom to make life choices", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Freedom to make life choices')

# %% [markdown]
# **The above plot shows that Happiness score increase with the increase in 'Freedom to make life choices' score.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: Generosity'], df_2022['Happiness score']).set_title("Happiness score vs Generosity",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Generosity')

# %% [markdown]
# **The above plot shows that 'Generosity' score have little to no effect on the Happiness score.**

# %%
df_2022.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: GDP per capita'], df_2022['Explained by: Healthy life expectancy']).set_title("Healthy life Expectancy vs GDP per capita",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Healthy life Expectancy vs GDP per capita')

# %% [markdown]
# **The above plot shows that GDP per capita have positive effect on the Healthy life expectancy.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: GDP per capita'], df_2022['Explained by: Generosity']).set_title("Generosity vs GDP per capita",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Generosity vs GDP per capita')

# %% [markdown]
# **The above plot shows that GDP per capita have a small negative effect on the Generosity.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: GDP per capita'], df_2022['Dystopia (1.83) + residual']).set_title("Dystopia vs GDP per capita",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Dystopia vs GDP per capita')

# %% [markdown]
# **The above plot shows that GDP per capita have a little effect on Dystopia.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: GDP per capita'], df_2022['Explained by: Perceptions of corruption']).set_title("Perceptions of corruption vs GDP per capita",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Perceptions of corruption vs GDP per capita')

# %% [markdown]
# **The above plot shows that "Perceptions of corruption" score increase with the increase in the GDP per capita.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: GDP per capita'], df_2022['Explained by: Freedom to make life choices']).set_title("Freedom to make life choices vs GDP per capita",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Freedom to make life choices vs GDP per capita')

# %% [markdown]
# **The above plot shows that Freedom to make life choices increase with the increase in the GDP per capita.**

# %%
plt.figure(figsize=(8,4))
sns.lineplot(df_2022['Explained by: GDP per capita'], df_2022['Explained by: Social support']).set_title("Social support vs GDP per capita",  fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Social support vs GDP per capita')

# %% [markdown]
# **The above plot shows that Social support increase with the increase in the GDP per capita.**

# %% [markdown]
# # Conclusion

# %% [markdown]
#  **The GDP per capita have a positive effect on the Healthy life Expectancy, Social Support, Freedom to make choices, Perceptions of corruption which in turns have a positive effect on the Hapiness score.**
